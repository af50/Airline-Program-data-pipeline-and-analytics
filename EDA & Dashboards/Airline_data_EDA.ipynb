# %%
import pandas as pd

# %%
df1 = pd.read_csv("Data\Airline Loyalty Data Dictionary.csv")
df2 = pd.read_csv("Data\Customer Flight Activity.csv")
df3 = pd.read_csv("Data\Customer Loyalty History.csv")
df4 = pd.read_csv("Data\Calendar.csv")

# %%
df1
# Out:
#                        Table                        Field  \
# 0   Customer Flight Activity               Loyalty Number
# 1                        NaN                         Year
# 2                        NaN                        Month
# 3                        NaN                Total Flights
# 4                        NaN                     Distance
# 5                        NaN           Points Accumulated
# 6                        NaN              Points Redeemed
# 7                        NaN  Dollar Cost Points Redeemed
# 8   Customer Loyalty History               Loyalty Number
# 9                        NaN                      Country
# 10                       NaN                     Province
# 11                       NaN                         City
# 12                       NaN                  Postal Code
# 13                       NaN                       Gender
# 14                       NaN                    Education
# ...

# %%
df2.head()
# Out:
#    Loyalty Number  Year  Month  Total Flights  Distance  Points Accumulated  \
# 0          100590  2018      6             12     15276             22914.0
# 1          100590  2018      7             12      9168             13752.0
# 2          100590  2018      5              4      6504              9756.0
# 3          100590  2018     10              0         0                 0.0
# 4          100590  2018      2              0         0                 0.0
#
#    Points Redeemed  Dollar Cost Points Redeemed
# 0                0                            0
# 1                0                            0
# 2                0                            0
# 3              512                           92
# 4                0                            0

# %%
check = df2.loc[df2['Loyalty Number'] == 100590].sort_values(by=['Year', 'Month'], ascending=[True, True])
check
# Out:
#     Loyalty Number  Year  Month  Total Flights  Distance  Points Accumulated  \
# 4           100590  2018      2              0         0                 0.0
# 6           100590  2018      3              0         0                 0.0
# 5           100590  2018      4              0         0                 0.0
# 2           100590  2018      5              4      6504              9756.0
# 0           100590  2018      6             12     15276             22914.0
# 1           100590  2018      7             12      9168             13752.0
# 7           100590  2018      8              0         0                 0.0
# 8           100590  2018      9              0         0                 0.0
# 3           100590  2018     10              0         0                 0.0
# 9           100590  2018     11              0         0                 0.0
# 10          100590  2018     12              0         0                 0.0
#
# ...

# %%
borders = [df4['Date'].min(), df4['Date'].max()]
borders
# Out:
# ['2012-01-01', '2018-12-31']

# %%
df2['Year'].value_counts()
# Out:
# Year
# 2018    201836
# 2017    191100
# Name: count, dtype: int64

# %%
df2['Loyalty Number'].nunique()
# Out:
# 16737

# %%
df3['Loyalty Number'].nunique()
# Out:
# 16737

# %%
df3.loc[df3['Loyalty Number'] == 100590, 'CLV']
# Out:
# 5754    34090.04
# Name: CLV, dtype: float64

# %%
df3.shape
# Out:
# (16737, 16)

# %%
df2['Loyalty Number'].nunique()
# Out:
# 16737

# %%
df2.shape
# Out:
# (392936, 8)

# %%
df3.head()
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
# ...

# %%
df3['Enrollment Type'].value_counts()
# Out:
# Enrollment Type
# Standard          15766
# 2018 Promotion      971
# Name: count, dtype: int64

# %%
df3.loc[df3['Cancellation Month'].isna(), 'Cancellation Year'].nunique()
# Out:
# 0

# %%
df3['Salary'].dtype
# Out:
# dtype('float64')

# %%
df2['Year'].value_counts()
# Out:
# Year
# 2018    201836
# 2017    191100
# Name: count, dtype: int64
